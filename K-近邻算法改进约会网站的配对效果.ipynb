# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 1、加载数据

# %%
train_df = pd.read_table('./input/datingTestSet.txt',header=None,names=['a','b','c','d'])

# %%
train_df.head()
# Out:
#        a          b         c           d
# 0  40920   8.326976  0.953952  largeDoses
# 1  14488   7.153469  1.673904  smallDoses
# 2  26052   1.441871  0.805124   didntLike
# 3  75136  13.147394  0.428964   didntLike
# 4  38344   1.669788  0.134296   didntLike

# %% [markdown]
# # 2、分析数据

# %% [markdown]
# 将D列数据转换为数值标签，通过scatter图分析数据

# %%
train_df['d'] =  pd.Categorical(train_df['d']).codes  
#plt.scatter(train_df['a'],train_df['c'],c=15*train_df['d'])
plt.scatter(train_df['a'],train_df['b'],c=15*train_df['d'])

# %% [markdown]
# # 3、准备数据：归一化数值

# %%
train_df.iloc[:,0:3] = (train_df.iloc[:,0:3] - train_df.iloc[:,0:3].min())/(train_df.iloc[:,0:3].max() - train_df.iloc[:,0:3].min())
#train_df.head()

# %% [markdown]
# # 4、建立模型

# %%
from sklearn.neighbors import KNeighborsClassifier
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 2))
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# D:\pyStudy\sklearn\__check_build\__init__.py in <module>()
#      43 try:
# ---> 44     from ._check_build import check_build
#      45 except ImportError as e:
#
# ModuleNotFoundError: No module named 'sklearn.__check_build._check_build'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-01404b4dc4c7> in <module>()
# ----> 1 from sklearn.neighbors import KNeighborsClassifier
#
# D:\pyStudy\sklearn\__init__.py in <module>()
#      54     # process, as it may not be compiled yet
#      55 else:
# ---> 56     from . import __check_build
# ...
